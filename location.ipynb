# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('zomato_extracted.csv')

# %%
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 12495  https://www.zomato.com/bangalore/sri-jayalaksh...
# 12496  https://www.zomato.com/bangalore/surya-bakery-...
# 12497  https://www.zomato.com/bangalore/cool-corner-a...
# 12498  https://www.zomato.com/bangalore/kc-das-sweet-...
# 12499  https://www.zomato.com/bangalore/bangalore-mas...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 12495  1, Lal Bagh Main Rd, Srinivas Colony, Sudhama ...
# 12496  45, Mission Road, Opp Sbi Bank, Shanti Nagar, ...
# 12497   27, St Johns Church Road, Frazer Town, Bangalore
# 12498           3D, Wheeler Road, Frazer Town, Bangalore
# 12499             46, 8th Main, Vasanth Nagar, Bangalore
#
#                              name online_order book_table   rate  votes  \
# 0                           Jalsa          Yes        Yes  4.1/5    775
# 1                  Spice Elephant          Yes         No  4.1/5    787
# 2                 San Churro Cafe          Yes         No  3.8/5    918
# 3           Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4                   Grand Village           No         No  3.8/5    166
# ...                           ...          ...        ...    ...    ...
# 12495      Sri Jayalakshmi Bakery           No         No  3.3/5      5
# 12496                Surya Bakery           No         No  3.5/5     21
# 12497  Cool Corner Arun Ice Cream           No         No  3.5/5      8
# 12498         KC Das - Sweet Bite           No         No  3.5/5     20
# 12499      Bangalore Masala House          Yes         No  4.2/5    255
#
#                                   phone       location  \
# 0        080 42297555\r\n+91 9743772233   Banashankari
# 1                          080 41714161   Banashankari
# 2                        +91 9663487993   Banashankari
# 3                        +91 9620009302   Banashankari
# 4      +91 8026612447\r\n+91 9901210005   Basavanagudi
# ...                                 ...            ...
# 12495                      080 22270078   Shanti Nagar
# 12496    080 41248811\r\n+91 9480648812   Shanti Nagar
# 12497                    +91 9830199012    Frazer Town
# 12498    080 25543107\r\n+91 9886201249    Frazer Town
# 12499    +91 9880118608\r\n080 48666224  Vasanth Nagar
#
#                      rest_type  \
# 0                Casual Dining
# 1                Casual Dining
# 2          Cafe, Casual Dining
# 3                  Quick Bites
# 4                Casual Dining
# ...                        ...
# 12495      Bakery, Quick Bites
# 12496                   Bakery
# 12497           Dessert Parlor
# 12498  Sweet Shop, Quick Bites
# 12499                     Cafe
#
#                                               dish_liked  \
# 0      Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1      Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2      Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                            Masala Dosa
# 4                                    Panipuri, Gol Gappe
# ...                                                  ...
# 12495                                                NaN
# 12496                                                NaN
# 12497                                                NaN
# 12498                                                NaN
# 12499  Peri Peri Chicken, Shikanji, Peri Peri Pizza, ...
#
#                              cuisines approx_cost(for two people)  \
# 0      North Indian, Mughlai, Chinese                         800
# 1         Chinese, North Indian, Thai                         800
# 2              Cafe, Mexican, Italian                         800
# 3          South Indian, North Indian                         300
# 4            North Indian, Rajasthani                         600
# ...                               ...                         ...
# 12495               Bakery, Beverages                         250
# 12496                          Bakery                         200
# 12497             Desserts, Ice Cream                         200
# 12498             Mithai, Street Food                         200
# 12499    Cafe, Continental, Fast Food                         500
#
#                                             reviews_list  \
# 0      [('Rated 4.0', 'RATED\n  A beautiful place to ...
# 1      [('Rated 4.0', 'RATED\n  Had been here for din...
# 2      [('Rated 3.0', "RATED\n  Ambience is not that ...
# 3      [('Rated 4.0', "RATED\n  Great food and proper...
# 4      [('Rated 4.0', 'RATED\n  Very good restaurant ...
# ...                                                  ...
# 12495                                                 []
# 12496  [('Rated 3.0', "RATED\n  Just Ok.\nVisually ap...
# 12497  [('Rated 5.0', 'RATED\n  Excellent service! Va...
# 12498  [('Rated 5.0', 'RATED\n  Lovely authentic swee...
# 12499  [('Rated 5.0', 'RATED\n  This place is just am...
#
#                                                menu_item listed_in(type)  \
# 0                                                     []          Buffet
# 1                                                     []          Buffet
# 2                                                     []          Buffet
# 3                                                     []          Buffet
# 4                                                     []          Buffet
# ...                                                  ...             ...
# 12495                                                 []        Desserts
# 12496                                                 []        Desserts
# 12497                                                 []        Desserts
# 12498                                                 []        Desserts
# 12499  ['Rajma with Rice Combo', 'BMH Sandwich', 'Bom...        Desserts
#
#       listed_in(city)
# 0        Banashankari
# 1        Banashankari
# 2        Banashankari
# 3        Banashankari
# 4        Banashankari
# ...               ...
# 12495   Church Street
# 12496   Church Street
# 12497   Church Street
# 12498   Church Street
# 12499   Church Street
#
# [12500 rows x 17 columns]

# %%
#check missing Value
df.isnull().sum()
# Out:
# url                               0
# address                           0
# name                              0
# online_order                      0
# book_table                        0
# rate                           1811
# votes                             0
# phone                           254
# location                          2
# rest_type                        56
# dish_liked                     6940
# cuisines                         10
# approx_cost(for two people)      33
# reviews_list                      0
# menu_item                         0
# listed_in(type)                   0
# listed_in(city)                   0
# dtype: int64

# %% [markdown]
# Search by location

# %%
location_df = df[['name', 'address']]
location_df = location_df[['name', 'address']].drop_duplicates()
location_df
# Out:
#                         name  \
# 0                      Jalsa
# 1             Spice Elephant
# 2            San Churro Cafe
# 3      Addhuri Udupi Bhojana
# 4              Grand Village
# ...                      ...
# 12412              Keventers
# 12425      Sreeraj Lassi Bar
# 12492         Karachi Bakery
# 12493  Sri Rama Vilas Sweets
# 12498    KC Das - Sweet Bite
#
#                                                  address
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 12412  24,Amphitheatre, UB City, Vittal Mallya Road, ...
# 12425  164, Chik Bazaar Road, Opposite Bus Stand, Shi...
# 12492             41, Coles Road, Frazer Town, Bangalore
# 12493  14, OTC Road, Near Dharmaraya Swamy Temple, Na...
# 12498           3D, Wheeler Road, Frazer Town, Bangalore
#
# [6439 rows x 2 columns]

# %%
pip install googlemaps
# Out:
# Collecting googlemaps
#   Using cached googlemaps-4.10.0-py3-none-any.whl
# Requirement already satisfied: requests<3.0,>=2.20.0 in c:\users\acer\anaconda3\lib\site-packages (from googlemaps) (2.32.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\acer\anaconda3\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\acer\anaconda3\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\acer\anaconda3\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\acer\anaconda3\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2024.7.4)
# Installing collected packages: googlemaps
# Successfully installed googlemaps-4.10.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import googlemaps
from urllib.parse import quote

# %%
# Initialize the Google Maps client with your API key
API_KEY = 'AIzaSyDK7boLSVOjAK2lPx6NoOrBYPaXLpCAUoA'
gmaps = googlemaps.Client(key=API_KEY)

# %%
def get_lat_long(name, address):
    """
    Fetches latitude and longitude for a given restaurant name and address using Google Geocoding API.

    Args:
    - name: The name of the restaurant.
    - address: The address of the restaurant.

    Returns:
    - A tuple containing latitude and longitude, or None if not found.
    """
    try:
        # Combine name and address for geocoding
        location = f"{name}, {address}"
        # Properly encode the location to handle special characters
        location_encoded = quote(location, safe='')
        geocode_result = gmaps.geocode(location_encoded)

        if geocode_result:
            lat = geocode_result[0]['geometry']['location']['lat']
            lng = geocode_result[0]['geometry']['location']['lng']
            return (lat, lng)
        else:
            return None
    except Exception as e:
        print(f"Error fetching data for {name}: {e}")
        return None

# Add Latitude and Longitude columns to the DataFrame
location_df['latitude'] = None
location_df['longitude'] = None

# Fetch and store lat/long for each restaurant
for idx, row in location_df.iterrows():
    lat_long = get_lat_long(row['name'], row['address'])
    if lat_long:
        location_df.at[idx, 'latitude'] = lat_long[0]
        location_df.at[idx, 'longitude'] = lat_long[1]

# Display the updated DataFrame
location_df
# Out:
#                         name  \
# 0                      Jalsa
# 1             Spice Elephant
# 2            San Churro Cafe
# 3      Addhuri Udupi Bhojana
# 4              Grand Village
# ...                      ...
# 12412              Keventers
# 12425      Sreeraj Lassi Bar
# 12492         Karachi Bakery
# 12493  Sri Rama Vilas Sweets
# 12498    KC Das - Sweet Bite
#
#                                                  address   latitude  longitude
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...  12.931417  77.554756
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...   12.91975   77.55471
# 2      1112, Next to KIMS Medical College, 17th Cross...       None       None
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...       None       None
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...       None       None
# ...                                                  ...        ...        ...
# 12412  24,Amphitheatre, UB City, Vittal Mallya Road, ...  12.971599  77.594563
# 12425  164, Chik Bazaar Road, Opposite Bus Stand, Shi...  39.001672 -77.403239
# 12492             41, Coles Road, Frazer Town, Bangalore   24.86222  67.406394
# 12493  14, OTC Road, Near Dharmaraya Swamy Temple, Na...  12.966716  77.583389
# 12498           3D, Wheeler Road, Frazer Town, Bangalore       None       None
#
# [6439 rows x 4 columns]

# %%
#Merging Two DataFrames
df_with_lat_lon = pd.merge(location_df, df[['name', 'address', 'url']], on=['name', 'address'], how='left')
#Selecting Relevant Columns and Removing Duplicates
df_with_lat_lon = df_with_lat_lon[['name', 'address', 'latitude', 'longitude', 'url']].drop_duplicates(subset=['name', 'address'])
# Saving the Result to Excel
df_with_lat_lon.to_excel('df_with_lat_lon.xlsx', index=False)
#Displaying the DataFrame
df_with_lat_lon
# Out:
#                         name  \
# 0                      Jalsa
# 6             Spice Elephant
# 10           San Churro Cafe
# 20     Addhuri Udupi Bhojana
# 22             Grand Village
# ...                      ...
# 12495              Keventers
# 12496      Sreeraj Lassi Bar
# 12497         Karachi Bakery
# 12498  Sri Rama Vilas Sweets
# 12499    KC Das - Sweet Bite
#
#                                                  address   latitude  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...  12.931417
# 6      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...   12.91975
# 10     1112, Next to KIMS Medical College, 17th Cross...       None
# 20     1st Floor, Annakuteera, 3rd Stage, Banashankar...       None
# 22     10, 3rd Floor, Lakshmi Associates, Gandhi Baza...       None
# ...                                                  ...        ...
# 12495  24,Amphitheatre, UB City, Vittal Mallya Road, ...  12.971599
# 12496  164, Chik Bazaar Road, Opposite Bus Stand, Shi...  39.001672
# 12497             41, Coles Road, Frazer Town, Bangalore   24.86222
# 12498  14, OTC Road, Near Dharmaraya Swamy Temple, Na...  12.966716
# 12499           3D, Wheeler Road, Frazer Town, Bangalore       None
#
#        longitude                                                url
# 0      77.554756  https://www.zomato.com/bangalore/jalsa-banasha...
# 6       77.55471  https://www.zomato.com/bangalore/spice-elephan...
# 10          None  https://www.zomato.com/SanchurroBangalore?cont...
# 20          None  https://www.zomato.com/bangalore/addhuri-udupi...
# 22          None  https://www.zomato.com/bangalore/grand-village...
# ...          ...                                                ...
# 12495  77.594563  https://www.zomato.com/bangalore/keventers-lav...
# 12496 -77.403239  https://www.zomato.com/bangalore/sreeraj-lassi...
# 12497  67.406394  https://www.zomato.com/bangalore/karachi-baker...
# 12498  77.583389  https://www.zomato.com/bangalore/sri-rama-vila...
# 12499       None  https://www.zomato.com/bangalore/kc-das-sweet-...
#
# [6439 rows x 5 columns]

# %%
# read the preprocessed dataset with restaurant name, address, url, latitude, and longitude
df_with_lat_lon = pd.read_excel('df_with_lat_lon.xlsx')

import ipywidgets as widgets
from IPython.display import display, clear_output
import googlemaps
from urllib.parse import quote
import numpy as np

# Initialize the Google Maps client with your API key
API_KEY = 'AIzaSyDK7boLSVOjAK2lPx6NoOrBYPaXLpCAUoA'
gmaps = googlemaps.Client(key=API_KEY)

def get_autocomplete_suggestions(input_text):
    """
    Fetches autocomplete suggestions for a given input text using Google Places API.

    Args:
    - input_text: The user's input text for location search.

    Returns:
    - A list of suggested place descriptions.
    """
    try:
        # Use the Google Places API autocomplete function
        suggestions = gmaps.places_autocomplete(input_text)
        return [suggestion['description'] for suggestion in suggestions]
    except Exception as e:
        print(f"Error fetching autocomplete suggestions: {e}")
        return []

def get_lat_long(address):
    """
    Fetches latitude and longitude for a given address using Google Geocoding API.

    Args:
    - address: The selected address from autocomplete suggestions.

    Returns:
    - A tuple containing latitude and longitude.
    """
    try:
        geocode_result = gmaps.geocode(address)
        if geocode_result:
            lat = geocode_result[0]['geometry']['location']['lat']
            lng = geocode_result[0]['geometry']['location']['lng']
            return (lat, lng)
    except Exception as e:
        print(f"Error fetching latitude and longitude: {e}")
    return None


def haversine(lat1, lon1, lat2, lon2):
    """Calculate the Haversine distance between two sets of lat/lon points."""
    R = 6371  # Earth radius in kilometers
    phi1, phi2 = np.radians(lat1), np.radians(lat2)
    dphi = np.radians(lat2 - lat1)
    dlambda = np.radians(lon2 - lon1)

    a = np.sin(dphi/2.0)**2 + np.cos(phi1) * np.cos(phi2) * np.sin(dlambda/2.0)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))
    return R * c

def find_nearby_restaurants(lat, lng, df, max_distance_km=5):
    """Finds restaurants within a given distance from a specified location."""
    df['distance'] = df.apply(lambda row: haversine(lat, lng, row['latitude'], row['longitude']), axis=1)
    nearby_restaurants = df[df['distance'] <= max_distance_km]
    return nearby_restaurants

def on_text_submit(change):
    """
    Handles the text submission event to display autocomplete suggestions
    when the Enter key is pressed.
    """
    clear_output(wait=True)
    user_input = change.value
    if user_input:
        suggestions = get_autocomplete_suggestions(user_input)
        if suggestions:
            dropdown.options = suggestions
            display(dropdown)
        else:
            print("No suggestions found.")

def on_option_select(change):
    """
    Handles the option selection event to fetch and display latitude and longitude
    of the selected location.
    """
    clear_output(wait=True)
    selected_address = change['new']
    if selected_address:
        coordinates = get_lat_long(selected_address)
        if coordinates:
            print(f"Selected Location: {selected_address}")
            print(f"Latitude: {coordinates[0]}, Longitude: {coordinates[1]}")

            # Find nearby restaurants
            nearby_restaurants = find_nearby_restaurants(coordinates[0], coordinates[1], df_with_lat_lon)
            if not nearby_restaurants.empty:
                print("\nRestaurants within 5 km:")
                display(nearby_restaurants[['name', 'latitude', 'longitude', 'distance', 'url']])
            else:
                print("No restaurants found within 5 km.")
        else:
            print("Could not fetch coordinates for the selected location.")



# Create an input widget for user text entry
text_input = widgets.Text(
    value='',
    placeholder='Type a location...',
    description='Location:',
    disabled=False
)

# Create a dropdown widget for displaying suggestions
dropdown = widgets.Dropdown(
    options=[],
    description='Select:',
    disabled=False
)

# Display the input widget
display(text_input)

# Attach handlers to the input and dropdown widgets
text_input.on_submit(on_text_submit)
dropdown.observe(on_option_select, names='value')
# Out:
# Text(value='', description='Location:', placeholder='Type a location...')
